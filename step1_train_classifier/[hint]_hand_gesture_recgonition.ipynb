# %%
# Tạo folder data để các bạn upload file 3 file data được tạo ra ở step 0 vào folder data
# Các bạn upload file hand_gesture.yaml ngoài folder data
# !mkdir D:\\data
# Out:
# A subdirectory or file D:\\data already exists.

# %%
# # Nếu đã chạy thành công step 0 thì các bạn không chạy cell này và chỉ upload 3 file data của các bạn vào thư mục data
# # Và upload file hand_gesture.yaml bên ngoài thư mục data
# # Nếu không chạy được ở step 0 thì các bạn run cell này để download data
# !gdown  1gzWOtABiVmJ38usCSDe5F9gR2tECt3zu -O data/
# !gdown  15lwipssmC_K82ukRfb0uVCiDH1TZ3QCf -O data/
# !gdown  1nIo1_wBmkovz-u_BCsV5c1Kbz6ZqoKwq -O data/
# # Download file hand_gesture.yam
# !gdown  1ZteHYSgbuZu_GcUJHW8ZzoZv1DE8-oLw

# %%
import os
import cv2
import yaml
import torch
import numpy as np
import pandas as pd
from  torch import nn
import mediapipe as mp
from torch import optim
from datetime import datetime
from torchmetrics import Accuracy
from torch.utils.data import Dataset

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        list_label = label_dict_from_config_file("D:/Tài liệu/AI/Main_course/Module 5/Week 5/Hint_light_controlling_using_hand_gesture/Hint/step0_generate_data/hand_gesture.yaml")
        '''Hoàn thành đoạn code để xây dựng một model gồm có 4 hidden layer,
            lần lượng input và output là (63, 128), (128, 128), (128, 128), (128, 128).
            Layer đầu tiên được theo sau bổi một Relu và Batchnorm1d.
            Layer thứ 2, 3, và 4 được theo sau bỏi Relu và Dropout với rate lần lượt là 0.4, 0.4, 0.6.
            Output layer có nhịêm vụ phân loại với input là 128 và output là số lượng class cử chỉ'''
        self.linear_relu_stack = nn.Sequential(           
            ################## Your Code Here ################## Q1           
            nn.Linear(63, 128),#Layer 1 
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Linear(128, 128),#Layer 2 
            nn.ReLU(),  
            nn.Dropout(0.4),
            nn.Linear(128, 128),#Layer 3
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(128, 128),#Layer 4
            nn.ReLU(),
            nn.Dropout(0.6),
            nn.Linear(128, 5)
            ####################################################
        )
    ''' Hoàn thành code để thực hiện forward dự đoán cử chỉ với input x.
    Thực hiện flatten x
    Pass x vừa flatten vào linear_relu_stack
    Return  logits (outputs từ layer cuối cùng)
        '''
    def forward(self, x):
        ################## Your Code Here ################## Q2
        x = self.flatten(x) 
        logits = self.linear_relu_stack(x) 
        return logits
        ####################################################

    def predict(self,x,threshold=0.8):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        chosen_ind = torch.argmax(softmax_prob,dim=1)
        return torch.where(softmax_prob[0,chosen_ind]>threshold,chosen_ind,-1)

    def predict_with_known_class(self,x):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        return torch.argmax(softmax_prob,dim=1)

    def score(self,logits):
        return -torch.amax(logits,dim=1)

# %%
def label_dict_from_config_file(relative_path):
    with open(relative_path,"r") as f:
       label_tag = yaml.full_load(f)["gestures"]
    return label_tag

# %%
class HandLandmarksDetector():
    def __init__(self) -> None:
        self.mp_drawing = mp.solutions.drawing_utils
        self.mp_drawing_styles = mp.solutions.drawing_styles
        self.mp_hands = mp.solutions.hands
        self.detector = self.mp_hands.Hands(False,max_num_hands=1,min_detection_confidence=0.5)

    def detectHand(self,frame):
        hands = []
        frame = cv2.flip(frame, 1)
        annotated_image = frame.copy()
        results = self.detector.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        if results.multi_hand_landmarks is not None:
            for hand_landmarks in results.multi_hand_landmarks:
                hand = []
                self.mp_drawing.draw_landmarks(
                    annotated_image,
                    hand_landmarks,
                    self.mp_hands.HAND_CONNECTIONS,
                    self.mp_drawing_styles.get_default_hand_landmarks_style(),
                    self.mp_drawing_styles.get_default_hand_connections_style())
                for landmark in hand_landmarks.landmark:
                    x,y,z = landmark.x,landmark.y,landmark.z
                    hand.extend([x,y,z])
            hands.append(hand)
        return hands,annotated_image

# %%
class CustomImageDataset(Dataset):
    def __init__(self, data_file):
        self.data = pd.read_csv(data_file)
        self.labels = torch.from_numpy(self.data.iloc[:,0].to_numpy())

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        one_hot_label = self.labels[idx]
        torch_data = torch.from_numpy(self.data.iloc[idx,1:].to_numpy(dtype=np.float32))
        return torch_data, one_hot_label

# %%
class EarlyStopper:
    def __init__(self, patience=1, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.watched_metrics = np.inf

    def early_stop(self, current_value):
        if current_value < self.watched_metrics:
            self.watched_metrics = current_value
            self.counter = 0
        elif current_value > (self.watched_metrics + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
def train(trainloader, val_loader, model, loss_function, early_stopper, optimizer):
    # add auroc score
    best_vloss = 1_000_000
    timestamp = datetime.now().strftime('%d-%m %H:%M')
    for epoch in range(300):
        #training step
        model.train(True)
        running_loss = 0.0
        acc_train = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for batch_number,data in enumerate(trainloader):
            inputs,labels = data

            ################## Your Code Here ################## Q9
            ''' Hoàn thành code để thực hiện reset gradients và dự đoán class cử
            chỉ của inputs
            '''
            optimizer.zero_grad() 
            preds = model(inputs)
            ####################################################

            ################## Your Code Here ################## Q10
            ''' Hoàn thành code để thực hiện tính loss dưa vào kết quả dự đoán
            và labels, sau đó thực hiện backwward và update parameters thông qua
            optimizer
            '''
            loss = loss_function(preds, labels)
            loss.backward() 
            optimizer.step() 
            ####################################################

            acc_train.update(model.predict_with_known_class(inputs), labels)
            running_loss += loss.item()
        avg_loss = running_loss / len(trainloader)
        # validating step
        model.train(False)
        running_vloss = 0.0
        acc_val = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for i, vdata in enumerate(val_loader):
            vinputs, vlabels = vdata
            preds = model(vinputs)
            vloss = loss_function(preds, vlabels)
            running_vloss += vloss.item()
            acc_val.update(model.predict_with_known_class(vinputs), vlabels)

        # Log the running loss averaged per batch
        # for both training and validation
        print(f"Epoch {epoch}: ")
        print(f"Accuracy train:{acc_train.compute().item()}, val:{acc_val.compute().item()}")
        avg_vloss = running_vloss / len(val_loader)
        print('LOSS train {} valid {}'.format(avg_loss, avg_vloss))
        print('Training vs. Validation Loss',
                        { 'Training' : avg_loss, 'Validation' : avg_vloss },
                        epoch + 1)
        print('Training vs. Validation accuracy',
                        { 'Training' : acc_train.compute().item()
                        , 'Validation' : acc_val.compute().item() },
                        epoch + 1)

        # Track best performance, and save the model's state
        if avg_vloss < best_vloss:
            best_vloss = avg_vloss
            best_model_path = f'D:/Tài liệu/AI/Main_course/Module 5/Week 5/Hint_light_controlling_using_hand_gesture/Hint/step0_generate_data/models'
            torch.save(model.state_dict(), best_model_path)

        if early_stopper.early_stop(avg_vloss):
            ################## Your Code Here ################## Q5
            ''' Hoàn thành đoạn code bên dướ để print ra epoch hiện tại và
            minimum watched metric và thoát loop
            '''
            print(f"stopping at epoch{epoch}, minimum:{early_stopper.watched_metrics}")
# 3           break

            ####################################################



    model_path = f'D:/Tài liệu/AI/Main_course/Module 5/Week 5/Hint_light_controlling_using_hand_gesture/Hint/step0_generate_data/models'
    torch.save(model.state_dict(), model_path)

    print(acc_val.compute())
    return model, best_model_path

# %%
DATA_FOLDER_PATH="D:\Tài liệu\AI\Main_course\Module 5\Week 5\Hint_light_controlling_using_hand_gesture\Hint\step0_generate_data\data2"
LIST_LABEL = label_dict_from_config_file("D:\Tài liệu\AI\Main_course\Module 5\Week 5\Hint_light_controlling_using_hand_gesture\Hint\step0_generate_data\hand_gesture.yaml")
train_path = os.path.join(DATA_FOLDER_PATH,"landmark_train.csv")
val_path = os.path.join(DATA_FOLDER_PATH,"landmark_val.csv")
save_path = './models'
os.makedirs(save_path,exist_ok=True)
'''Hoàn thành code để thực hiện khởi tạo DataLoader cho trainset với
    batch_size 40 và cho phép xáo trộn '''
trainset = CustomImageDataset(train_path)
################## Your Code Here ################## Q3
trainloader = torch.utils.data.DataLoader(trainset, batch_size=40, shuffle=True)
####################################################

valset = CustomImageDataset(os.path.join(val_path))
val_loader = torch.utils.data.DataLoader(valset,batch_size=50, shuffle=False)

################## Your Code Here ################## Q8
'''Hoàn thành code để thực hiện khởi tạo NeuralNetwork model đã xây dựng ở trên,
khởi tạo hàm loss sử dụng CrossEntropyLoss và khởi tạo early stopper với patience
là 30 và min_delta là 0.01
'''
model = NeuralNetwork()
loss_function = nn.CrossEntropyLoss()
early_stopper = EarlyStopper(patience=30, min_delta=0.01)
####################################################

################## Your Code Here ################## Q4
'''Hoàn thành code để thực hiện cấu hình Adam optimizer cho các tham số của
model với tốc độ học là 0.0001
'''
optimizer = optim.Adam(model.parameters(), lr=0.0001)
####################################################


model, best_model_path = train(trainloader, val_loader, model, loss_function, early_stopper, optimizer)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# <>:2: SyntaxWarning: invalid escape sequence '\T'
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# <>:2: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\MinhPhu\AppData\Local\Temp\ipykernel_26932\49791128.py:1: SyntaxWarning: invalid escape sequence '\T'
#   DATA_FOLDER_PATH="D:\Tài liệu\AI\Main_course\Module 5\Week 5\Hint_light_controlling_using_hand_gesture\Hint\step0_generate_data\data2"
# C:\Users\MinhPhu\AppData\Local\Temp\ipykernel_26932\49791128.py:2: SyntaxWarning: invalid escape sequence '\T'
#   LIST_LABEL = label_dict_from_config_file("D:\Tài liệu\AI\Main_course\Module 5\Week 5\Hint_light_controlling_using_hand_gesture\Hint\step0_generate_data\hand_gesture.yaml")
# Epoch 0:
# Accuracy train:0.06896551698446274, val:0.08849557489156723
# LOSS train 1.6495003375140103 valid 1.6357692309788294
# Training vs. Validation Loss {'Training': 1.6495003375140103, 'Validation': 1.6357692309788294} 1
# Training vs. Validation accuracy {'Training': 0.06896551698446274, 'Validation': 0.08849557489156723} 1
# Epoch 1:
# Accuracy train:0.1034482792019844, val:0.08849557489156723
# LOSS train 1.6086137945001775 valid 1.6192895003727503
# Training vs. Validation Loss {'Training': 1.6086137945001775, 'Validation': 1.6192895003727503} 2
# Training vs. Validation accuracy {'Training': 0.1034482792019844, 'Validation': 0.08849557489156723} 2
# Epoch 2:
# Accuracy train:0.2298850566148758, val:0.1946902722120285
# LOSS train 1.5770888545296409 valid 1.5891306059701102
# Training vs. Validation Loss {'Training': 1.5770888545296409, 'Validation': 1.5891306059701102} 3
# Training vs. Validation accuracy {'Training': 0.2298850566148758, 'Validation': 0.1946902722120285} 3
# Epoch 3:
# Accuracy train:0.4045976996421814, val:0.516224205493927
# LOSS train 1.5369782881303267 valid 1.5522520712443761
# Training vs. Validation Loss {'Training': 1.5369782881303267, 'Validation': 1.5522520712443761} 4
# Training vs. Validation accuracy {'Training': 0.4045976996421814, 'Validation': 0.516224205493927} 4
# Epoch 4:
# Accuracy train:0.5747126340866089, val:0.516224205493927
# LOSS train 1.4804344068874011 valid 1.5131868124008179
# Training vs. Validation Loss {'Training': 1.4804344068874011, 'Validation': 1.5131868124008179} 5
# Training vs. Validation accuracy {'Training': 0.5747126340866089, 'Validation': 0.516224205493927} 5
# Epoch 5:
# Accuracy train:0.6482758522033691, val:0.516224205493927
# LOSS train 1.3983794992620295 valid 1.464984961918422
# Training vs. Validation Loss {'Training': 1.3983794992620295, 'Validation': 1.464984961918422} 6
# Training vs. Validation accuracy {'Training': 0.6482758522033691, 'Validation': 0.516224205493927} 6
# Epoch 6:
# Accuracy train:0.6873562932014465, val:0.516224205493927
# LOSS train 1.3247308839451184 valid 1.412851367677961
# Training vs. Validation Loss {'Training': 1.3247308839451184, 'Validation': 1.412851367677961} 7
# Training vs. Validation accuracy {'Training': 0.6873562932014465, 'Validation': 0.516224205493927} 7
# Epoch 7:
# Accuracy train:0.6873562932014465, val:0.516224205493927
# LOSS train 1.2163126360286365 valid 1.3604725769587926
# Training vs. Validation Loss {'Training': 1.2163126360286365, 'Validation': 1.3604725769587926} 8
# Training vs. Validation accuracy {'Training': 0.6873562932014465, 'Validation': 0.516224205493927} 8
# Epoch 8:
# Accuracy train:0.7103448510169983, val:0.516224205493927
# LOSS train 1.0684308301318775 valid 1.319647022656032
# Training vs. Validation Loss {'Training': 1.0684308301318775, 'Validation': 1.319647022656032} 9
# Training vs. Validation accuracy {'Training': 0.7103448510169983, 'Validation': 0.516224205493927} 9
# Epoch 9:
# Accuracy train:0.6988505721092224, val:0.516224205493927
# LOSS train 0.9431438716975126 valid 1.325064676148551
# Training vs. Validation Loss {'Training': 0.9431438716975126, 'Validation': 1.325064676148551} 10
# Training vs. Validation accuracy {'Training': 0.6988505721092224, 'Validation': 0.516224205493927} 10
# Epoch 10:
# Accuracy train:0.6896551847457886, val:0.516224205493927
# LOSS train 0.8219444860111583 valid 1.4386947410447257
# Training vs. Validation Loss {'Training': 0.8219444860111583, 'Validation': 1.4386947410447257} 11
# Training vs. Validation accuracy {'Training': 0.6896551847457886, 'Validation': 0.516224205493927} 11
# Epoch 11:
# Accuracy train:0.705747127532959, val:0.516224205493927
# LOSS train 0.7438923120498657 valid 1.6029693319329195
# Training vs. Validation Loss {'Training': 0.7438923120498657, 'Validation': 1.6029693319329195} 12
# Training vs. Validation accuracy {'Training': 0.705747127532959, 'Validation': 0.516224205493927} 12
# Epoch 12:
# Accuracy train:0.7126436829566956, val:0.516224205493927
# LOSS train 0.6647147969766096 valid 1.8248026889881916
# Training vs. Validation Loss {'Training': 0.6647147969766096, 'Validation': 1.8248026889881916} 13
# Training vs. Validation accuracy {'Training': 0.7126436829566956, 'Validation': 0.516224205493927} 13
# Epoch 13:
# Accuracy train:0.7333333492279053, val:0.516224205493927
# LOSS train 0.6172756444324147 valid 1.9902550398505159
# Training vs. Validation Loss {'Training': 0.6172756444324147, 'Validation': 1.9902550398505159} 14
# Training vs. Validation accuracy {'Training': 0.7333333492279053, 'Validation': 0.516224205493927} 14
# Epoch 14:
# Accuracy train:0.7241379022598267, val:0.516224205493927
# LOSS train 0.579841283234683 valid 2.2062256814512824
# Training vs. Validation Loss {'Training': 0.579841283234683, 'Validation': 2.2062256814512824} 15
# Training vs. Validation accuracy {'Training': 0.7241379022598267, 'Validation': 0.516224205493927} 15
# Epoch 15:
# Accuracy train:0.7402299046516418, val:0.516224205493927
# LOSS train 0.5592629530213096 valid 2.3628736684497977
# Training vs. Validation Loss {'Training': 0.5592629530213096, 'Validation': 2.3628736684497977} 16
# Training vs. Validation accuracy {'Training': 0.7402299046516418, 'Validation': 0.516224205493927} 16
# Epoch 16:
# Accuracy train:0.7425287365913391, val:0.516224205493927
# LOSS train 0.5398792163892225 valid 2.558959032674985
# Training vs. Validation Loss {'Training': 0.5398792163892225, 'Validation': 2.558959032674985} 17
# Training vs. Validation accuracy {'Training': 0.7425287365913391, 'Validation': 0.516224205493927} 17
# Epoch 17:
# Accuracy train:0.7471264600753784, val:0.516224205493927
# LOSS train 0.5230627628889951 valid 2.6508850497193635
# Training vs. Validation Loss {'Training': 0.5230627628889951, 'Validation': 2.6508850497193635} 18
# Training vs. Validation accuracy {'Training': 0.7471264600753784, 'Validation': 0.516224205493927} 18
# Epoch 18:
# Accuracy train:0.7632184028625488, val:0.516224205493927
# LOSS train 0.48583595861088147 valid 2.739588073887197
# Training vs. Validation Loss {'Training': 0.48583595861088147, 'Validation': 2.739588073887197} 19
# Training vs. Validation accuracy {'Training': 0.7632184028625488, 'Validation': 0.516224205493927} 19
# Epoch 19:
# Accuracy train:0.7586206793785095, val:0.516224205493927
# LOSS train 0.4981523101980036 valid 2.8633545976564556
# Training vs. Validation Loss {'Training': 0.4981523101980036, 'Validation': 2.8633545976564556} 20
# Training vs. Validation accuracy {'Training': 0.7586206793785095, 'Validation': 0.516224205493927} 20
# Epoch 20:
# Accuracy train:0.777011513710022, val:0.516224205493927
# LOSS train 0.4578092477538369 valid 2.895804333101426
# Training vs. Validation Loss {'Training': 0.4578092477538369, 'Validation': 2.895804333101426} 21
# Training vs. Validation accuracy {'Training': 0.777011513710022, 'Validation': 0.516224205493927} 21
# Epoch 21:
# Accuracy train:0.7839080691337585, val:0.516224205493927
# LOSS train 0.4380379319190979 valid 3.017369172610675
# Training vs. Validation Loss {'Training': 0.4380379319190979, 'Validation': 3.017369172610675} 22
# Training vs. Validation accuracy {'Training': 0.7839080691337585, 'Validation': 0.516224205493927} 22
# Epoch 22:
# Accuracy train:0.7908046245574951, val:0.516224205493927
# LOSS train 0.43145133690400556 valid 3.112545944816832
# Training vs. Validation Loss {'Training': 0.43145133690400556, 'Validation': 3.112545944816832} 23
# Training vs. Validation accuracy {'Training': 0.7908046245574951, 'Validation': 0.516224205493927} 23
# Epoch 23:
# Accuracy train:0.800000011920929, val:0.516224205493927
# LOSS train 0.4060209081931548 valid 3.2460188480493213
# Training vs. Validation Loss {'Training': 0.4060209081931548, 'Validation': 3.2460188480493213} 24
# Training vs. Validation accuracy {'Training': 0.800000011920929, 'Validation': 0.516224205493927} 24
# Epoch 24:
# Accuracy train:0.8022988438606262, val:0.516224205493927
# LOSS train 0.39412871680476447 valid 3.2960638266272975
# Training vs. Validation Loss {'Training': 0.39412871680476447, 'Validation': 3.2960638266272975} 25
# Training vs. Validation accuracy {'Training': 0.8022988438606262, 'Validation': 0.516224205493927} 25
# Epoch 25:
# Accuracy train:0.8068965673446655, val:0.516224205493927
# LOSS train 0.418035474690524 valid 3.46827643164683
# Training vs. Validation Loss {'Training': 0.418035474690524, 'Validation': 3.46827643164683} 26
# Training vs. Validation accuracy {'Training': 0.8068965673446655, 'Validation': 0.516224205493927} 26
# Epoch 26:
# Accuracy train:0.8206896781921387, val:0.516224205493927
# LOSS train 0.3873584378849376 valid 3.4566140281635205
# Training vs. Validation Loss {'Training': 0.3873584378849376, 'Validation': 3.4566140281635205} 27
# Training vs. Validation accuracy {'Training': 0.8206896781921387, 'Validation': 0.516224205493927} 27
# Epoch 27:
# Accuracy train:0.8252873420715332, val:0.516224205493927
# LOSS train 0.38071065734733234 valid 3.483474309248517
# Training vs. Validation Loss {'Training': 0.38071065734733234, 'Validation': 3.483474309248517} 28
# Training vs. Validation accuracy {'Training': 0.8252873420715332, 'Validation': 0.516224205493927} 28
# Epoch 28:
# Accuracy train:0.8229885101318359, val:0.516224205493927
# LOSS train 0.38416020436720416 valid 3.671096391032084
# Training vs. Validation Loss {'Training': 0.38416020436720416, 'Validation': 3.671096391032084} 29
# Training vs. Validation accuracy {'Training': 0.8229885101318359, 'Validation': 0.516224205493927} 29
# Epoch 29:
# Accuracy train:0.8229885101318359, val:0.516224205493927
# LOSS train 0.36968234181404114 valid 3.8603818607932356
# Training vs. Validation Loss {'Training': 0.36968234181404114, 'Validation': 3.8603818607932356} 30
# Training vs. Validation accuracy {'Training': 0.8229885101318359, 'Validation': 0.516224205493927} 30
# Epoch 30:
# Accuracy train:0.8275862336158752, val:0.516224205493927
# LOSS train 0.35986775024370715 valid 3.873266158642114
# Training vs. Validation Loss {'Training': 0.35986775024370715, 'Validation': 3.873266158642114} 31
# Training vs. Validation accuracy {'Training': 0.8275862336158752, 'Validation': 0.516224205493927} 31
# Epoch 31:
# Accuracy train:0.8298850655555725, val:0.516224205493927
# LOSS train 0.3489270535382358 valid 3.9172521848086035
# Training vs. Validation Loss {'Training': 0.3489270535382358, 'Validation': 3.9172521848086035} 32
# Training vs. Validation accuracy {'Training': 0.8298850655555725, 'Validation': 0.516224205493927} 32
# Epoch 32:
# Accuracy train:0.8390804529190063, val:0.516224205493927
# LOSS train 0.3416463705626401 valid 3.938407690750734
# Training vs. Validation Loss {'Training': 0.3416463705626401, 'Validation': 3.938407690750734} 33
# Training vs. Validation accuracy {'Training': 0.8390804529190063, 'Validation': 0.516224205493927} 33
# Epoch 33:
# Accuracy train:0.8574712872505188, val:0.516224205493927
# LOSS train 0.34338797493414447 valid 3.8983244454326007
# Training vs. Validation Loss {'Training': 0.34338797493414447, 'Validation': 3.8983244454326007} 34
# Training vs. Validation accuracy {'Training': 0.8574712872505188, 'Validation': 0.516224205493927} 34
# Epoch 34:
# Accuracy train:0.8620689511299133, val:0.516224205493927
# LOSS train 0.33067896284840326 valid 4.019322873775049
# Training vs. Validation Loss {'Training': 0.33067896284840326, 'Validation': 4.019322873775049} 35
# Training vs. Validation accuracy {'Training': 0.8620689511299133, 'Validation': 0.516224205493927} 35
# Epoch 35:
# Accuracy train:0.8528735637664795, val:0.516224205493927
# LOSS train 0.33036214926026086 valid 4.2333782443009635
# Training vs. Validation Loss {'Training': 0.33036214926026086, 'Validation': 4.2333782443009635} 36
# Training vs. Validation accuracy {'Training': 0.8528735637664795, 'Validation': 0.516224205493927} 36
# Epoch 36:
# Accuracy train:0.8643678426742554, val:0.516224205493927
# LOSS train 0.32626705819910223 valid 4.43394376222828
# Training vs. Validation Loss {'Training': 0.32626705819910223, 'Validation': 4.43394376222828} 37
# Training vs. Validation accuracy {'Training': 0.8643678426742554, 'Validation': 0.516224205493927} 37
# Epoch 37:
# Accuracy train:0.8850574493408203, val:0.516224205493927
# LOSS train 0.3070709231224927 valid 4.316093823952542
# Training vs. Validation Loss {'Training': 0.3070709231224927, 'Validation': 4.316093823952542} 38
# Training vs. Validation accuracy {'Training': 0.8850574493408203, 'Validation': 0.516224205493927} 38
# Epoch 38:
# Accuracy train:0.8896551728248596, val:0.516224205493927
# LOSS train 0.30722362209450116 valid 4.301507894587952
# Training vs. Validation Loss {'Training': 0.30722362209450116, 'Validation': 4.301507894587952} 39
# Training vs. Validation accuracy {'Training': 0.8896551728248596, 'Validation': 0.516224205493927} 39
# Epoch 39:
# Accuracy train:0.8873563408851624, val:0.516224205493927
# LOSS train 0.3041267449205572 valid 4.307616640656696
# Training vs. Validation Loss {'Training': 0.3041267449205572, 'Validation': 4.307616640656696} 40
# Training vs. Validation accuracy {'Training': 0.8873563408851624, 'Validation': 0.516224205493927} 40
# stopping at epoch39, minimum:1.319647022656032
# Epoch 40:
# Accuracy train:0.8712643384933472, val:0.516224205493927
# LOSS train 0.28512178564613516 valid 4.515542906509966
# Training vs. Validation Loss {'Training': 0.28512178564613516, 'Validation': 4.515542906509966} 41
# Training vs. Validation accuracy {'Training': 0.8712643384933472, 'Validation': 0.516224205493927} 41
# stopping at epoch40, minimum:1.319647022656032
# Epoch 41:
# Accuracy train:0.8896551728248596, val:0.516224205493927
# LOSS train 0.2857497889887203 valid 4.536586550203667
# Training vs. Validation Loss {'Training': 0.2857497889887203, 'Validation': 4.536586550203667} 42
# Training vs. Validation accuracy {'Training': 0.8896551728248596, 'Validation': 0.516224205493927} 42
# stopping at epoch41, minimum:1.319647022656032
# Epoch 42:
# Accuracy train:0.9011494517326355, val:0.516224205493927
# LOSS train 0.2696430330926722 valid 4.6369727604942454
# Training vs. Validation Loss {'Training': 0.2696430330926722, 'Validation': 4.6369727604942454} 43
# Training vs. Validation accuracy {'Training': 0.9011494517326355, 'Validation': 0.516224205493927} 43
# stopping at epoch42, minimum:1.319647022656032
# Epoch 43:
# Accuracy train:0.9011494517326355, val:0.516224205493927
# LOSS train 0.27162403816526587 valid 4.618681268336721
# Training vs. Validation Loss {'Training': 0.27162403816526587, 'Validation': 4.618681268336721} 44
# Training vs. Validation accuracy {'Training': 0.9011494517326355, 'Validation': 0.516224205493927} 44
# stopping at epoch43, minimum:1.319647022656032
# Epoch 44:
# Accuracy train:0.9103448390960693, val:0.516224205493927
# LOSS train 0.2612901533191854 valid 4.81412209881585
# Training vs. Validation Loss {'Training': 0.2612901533191854, 'Validation': 4.81412209881585} 45
# Training vs. Validation accuracy {'Training': 0.9103448390960693, 'Validation': 0.516224205493927} 45
# stopping at epoch44, minimum:1.319647022656032
# Epoch 45:
# Accuracy train:0.9218390583992004, val:0.516224205493927
# LOSS train 0.24570306593721564 valid 4.752446083685364
# Training vs. Validation Loss {'Training': 0.24570306593721564, 'Validation': 4.752446083685364} 46
# Training vs. Validation accuracy {'Training': 0.9218390583992004, 'Validation': 0.516224205493927} 46
# stopping at epoch45, minimum:1.319647022656032
# Epoch 46:
# Accuracy train:0.9195402264595032, val:0.516224205493927
# LOSS train 0.24508843232284894 valid 4.773183438608352
# Training vs. Validation Loss {'Training': 0.24508843232284894, 'Validation': 4.773183438608352} 47
# Training vs. Validation accuracy {'Training': 0.9195402264595032, 'Validation': 0.516224205493927} 47
# stopping at epoch46, minimum:1.319647022656032
# Epoch 47:
# Accuracy train:0.9241379499435425, val:0.516224205493927
# LOSS train 0.23397101326422257 valid 4.853117001776939
# Training vs. Validation Loss {'Training': 0.23397101326422257, 'Validation': 4.853117001776939} 48
# Training vs. Validation accuracy {'Training': 0.9241379499435425, 'Validation': 0.516224205493927} 48
# stopping at epoch47, minimum:1.319647022656032
# Epoch 48:
# Accuracy train:0.9379310607910156, val:0.516224205493927
# LOSS train 0.22453686527230524 valid 5.023664388462358
# Training vs. Validation Loss {'Training': 0.22453686527230524, 'Validation': 5.023664388462358} 49
# Training vs. Validation accuracy {'Training': 0.9379310607910156, 'Validation': 0.516224205493927} 49
# stopping at epoch48, minimum:1.319647022656032
# Epoch 49:
# Accuracy train:0.928735613822937, val:0.516224205493927
# LOSS train 0.2172163040800528 valid 4.855629258784185
# Training vs. Validation Loss {'Training': 0.2172163040800528, 'Validation': 4.855629258784185} 50
# Training vs. Validation accuracy {'Training': 0.928735613822937, 'Validation': 0.516224205493927} 50
# stopping at epoch49, minimum:1.319647022656032
# Epoch 50:
# Accuracy train:0.9425287246704102, val:0.516224205493927
# LOSS train 0.20311751419847662 valid 5.020619142239282
# Training vs. Validation Loss {'Training': 0.20311751419847662, 'Validation': 5.020619142239282} 51
# Training vs. Validation accuracy {'Training': 0.9425287246704102, 'Validation': 0.516224205493927} 51
# stopping at epoch50, minimum:1.319647022656032
# Epoch 51:
# Accuracy train:0.9563218355178833, val:0.516224205493927
# LOSS train 0.18280166573822498 valid 4.931250588329151
# Training vs. Validation Loss {'Training': 0.18280166573822498, 'Validation': 4.931250588329151} 52
# Training vs. Validation accuracy {'Training': 0.9563218355178833, 'Validation': 0.516224205493927} 52
# stopping at epoch51, minimum:1.319647022656032
# Epoch 52:
# Accuracy train:0.9655172228813171, val:0.516224205493927
# LOSS train 0.18495050208135086 valid 5.054959037466817
# Training vs. Validation Loss {'Training': 0.18495050208135086, 'Validation': 5.054959037466817} 53
# Training vs. Validation accuracy {'Training': 0.9655172228813171, 'Validation': 0.516224205493927} 53
# stopping at epoch52, minimum:1.319647022656032
# Epoch 53:
# Accuracy train:0.9655172228813171, val:0.516224205493927
# LOSS train 0.16924839940938083 valid 5.2228474848003055
# Training vs. Validation Loss {'Training': 0.16924839940938083, 'Validation': 5.2228474848003055} 54
# Training vs. Validation accuracy {'Training': 0.9655172228813171, 'Validation': 0.516224205493927} 54
# stopping at epoch53, minimum:1.319647022656032
# Epoch 54:
# Accuracy train:0.9678161144256592, val:0.516224205493927
# LOSS train 0.15382101386785507 valid 5.173671414167724
# Training vs. Validation Loss {'Training': 0.15382101386785507, 'Validation': 5.173671414167724} 55
# Training vs. Validation accuracy {'Training': 0.9678161144256592, 'Validation': 0.516224205493927} 55
# stopping at epoch54, minimum:1.319647022656032
# Epoch 55:
# Accuracy train:0.9793103337287903, val:0.516224205493927
# LOSS train 0.15578436783768915 valid 5.052804727969227
# Training vs. Validation Loss {'Training': 0.15578436783768915, 'Validation': 5.052804727969227} 56
# Training vs. Validation accuracy {'Training': 0.9793103337287903, 'Validation': 0.516224205493927} 56
# stopping at epoch55, minimum:1.319647022656032
# Epoch 56:
# Accuracy train:0.9862068891525269, val:0.516224205493927
# LOSS train 0.13916749507188797 valid 5.186342641962385
# Training vs. Validation Loss {'Training': 0.13916749507188797, 'Validation': 5.186342641962385} 57
# Training vs. Validation accuracy {'Training': 0.9862068891525269, 'Validation': 0.516224205493927} 57
# stopping at epoch56, minimum:1.319647022656032
# Epoch 57:
# Accuracy train:0.9931034445762634, val:0.516224205493927
# LOSS train 0.12961098145354877 valid 5.176756256349758
# Training vs. Validation Loss {'Training': 0.12961098145354877, 'Validation': 5.176756256349758} 58
# Training vs. Validation accuracy {'Training': 0.9931034445762634, 'Validation': 0.516224205493927} 58
# stopping at epoch57, minimum:1.319647022656032
# Epoch 58:
# Accuracy train:0.9885057210922241, val:0.516224205493927
# LOSS train 0.1139353427358649 valid 5.322064857906947
# Training vs. Validation Loss {'Training': 0.1139353427358649, 'Validation': 5.322064857906947} 59
# Training vs. Validation accuracy {'Training': 0.9885057210922241, 'Validation': 0.516224205493927} 59
# stopping at epoch58, minimum:1.319647022656032
# Epoch 59:
# Accuracy train:0.9862068891525269, val:0.516224205493927
# LOSS train 0.10650476948781447 valid 5.2737392207881
# Training vs. Validation Loss {'Training': 0.10650476948781447, 'Validation': 5.2737392207881} 60
# Training vs. Validation accuracy {'Training': 0.9862068891525269, 'Validation': 0.516224205493927} 60
# stopping at epoch59, minimum:1.319647022656032
# Epoch 60:
# Accuracy train:0.9816091656684875, val:0.516224205493927
# LOSS train 0.08778814734383063 valid 5.303169780276481
# Training vs. Validation Loss {'Training': 0.08778814734383063, 'Validation': 5.303169780276481} 61
# Training vs. Validation accuracy {'Training': 0.9816091656684875, 'Validation': 0.516224205493927} 61
# stopping at epoch60, minimum:1.319647022656032
# Epoch 61:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.08424663425169208 valid 5.300965636785544
# Training vs. Validation Loss {'Training': 0.08424663425169208, 'Validation': 5.300965636785544} 62
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 62
# stopping at epoch61, minimum:1.319647022656032
# Epoch 62:
# Accuracy train:0.9977011680603027, val:0.516224205493927
# LOSS train 0.07616548172452232 valid 5.301036716238871
# Training vs. Validation Loss {'Training': 0.07616548172452232, 'Validation': 5.301036716238871} 63
# Training vs. Validation accuracy {'Training': 0.9977011680603027, 'Validation': 0.516224205493927} 63
# stopping at epoch62, minimum:1.319647022656032
# Epoch 63:
# Accuracy train:0.9862068891525269, val:0.516224205493927
# LOSS train 0.07907627692276781 valid 5.369135133433247
# Training vs. Validation Loss {'Training': 0.07907627692276781, 'Validation': 5.369135133433247} 64
# Training vs. Validation accuracy {'Training': 0.9862068891525269, 'Validation': 0.516224205493927} 64
# stopping at epoch63, minimum:1.319647022656032
# Epoch 64:
# Accuracy train:0.9931034445762634, val:0.516224205493927
# LOSS train 0.06171955997970971 valid 5.419361162810934
# Training vs. Validation Loss {'Training': 0.06171955997970971, 'Validation': 5.419361162810934} 65
# Training vs. Validation accuracy {'Training': 0.9931034445762634, 'Validation': 0.516224205493927} 65
# stopping at epoch64, minimum:1.319647022656032
# Epoch 65:
# Accuracy train:0.9954022765159607, val:0.516224205493927
# LOSS train 0.0587609103796157 valid 5.691335220819318
# Training vs. Validation Loss {'Training': 0.0587609103796157, 'Validation': 5.691335220819318} 66
# Training vs. Validation accuracy {'Training': 0.9954022765159607, 'Validation': 0.516224205493927} 66
# stopping at epoch65, minimum:1.319647022656032
# Epoch 66:
# Accuracy train:0.9977011680603027, val:0.516224205493927
# LOSS train 0.05533002858812159 valid 5.492886879315328
# Training vs. Validation Loss {'Training': 0.05533002858812159, 'Validation': 5.492886879315328} 67
# Training vs. Validation accuracy {'Training': 0.9977011680603027, 'Validation': 0.516224205493927} 67
# stopping at epoch66, minimum:1.319647022656032
# Epoch 67:
# Accuracy train:0.9908046126365662, val:0.516224205493927
# LOSS train 0.03896674496883696 valid 5.435547374510471
# Training vs. Validation Loss {'Training': 0.03896674496883696, 'Validation': 5.435547374510471} 68
# Training vs. Validation accuracy {'Training': 0.9908046126365662, 'Validation': 0.516224205493927} 68
# stopping at epoch67, minimum:1.319647022656032
# Epoch 68:
# Accuracy train:0.9977011680603027, val:0.516224205493927
# LOSS train 0.04722423106431961 valid 5.660390586943971
# Training vs. Validation Loss {'Training': 0.04722423106431961, 'Validation': 5.660390586943971} 69
# Training vs. Validation accuracy {'Training': 0.9977011680603027, 'Validation': 0.516224205493927} 69
# stopping at epoch68, minimum:1.319647022656032
# Epoch 69:
# Accuracy train:0.9954022765159607, val:0.516224205493927
# LOSS train 0.04643165370957418 valid 5.565929911166028
# Training vs. Validation Loss {'Training': 0.04643165370957418, 'Validation': 5.565929911166028} 70
# Training vs. Validation accuracy {'Training': 0.9954022765159607, 'Validation': 0.516224205493927} 70
# stopping at epoch69, minimum:1.319647022656032
# Epoch 70:
# Accuracy train:0.9977011680603027, val:0.516224205493927
# LOSS train 0.035205423747274006 valid 5.680657302746048
# Training vs. Validation Loss {'Training': 0.035205423747274006, 'Validation': 5.680657302746048} 71
# Training vs. Validation accuracy {'Training': 0.9977011680603027, 'Validation': 0.516224205493927} 71
# stopping at epoch70, minimum:1.319647022656032
# Epoch 71:
# Accuracy train:0.9954022765159607, val:0.516224205493927
# LOSS train 0.02614596604623578 valid 5.7015435819886795
# Training vs. Validation Loss {'Training': 0.02614596604623578, 'Validation': 5.7015435819886795} 72
# Training vs. Validation accuracy {'Training': 0.9954022765159607, 'Validation': 0.516224205493927} 72
# stopping at epoch71, minimum:1.319647022656032
# Epoch 72:
# Accuracy train:0.9954022765159607, val:0.516224205493927
# LOSS train 0.03313479394736615 valid 5.552288426704698
# Training vs. Validation Loss {'Training': 0.03313479394736615, 'Validation': 5.552288426704698} 73
# Training vs. Validation accuracy {'Training': 0.9954022765159607, 'Validation': 0.516224205493927} 73
# stopping at epoch72, minimum:1.319647022656032
# Epoch 73:
# Accuracy train:0.9954022765159607, val:0.516224205493927
# LOSS train 0.029724363999610596 valid 5.789746566377971
# Training vs. Validation Loss {'Training': 0.029724363999610596, 'Validation': 5.789746566377971} 74
# Training vs. Validation accuracy {'Training': 0.9954022765159607, 'Validation': 0.516224205493927} 74
# stopping at epoch73, minimum:1.319647022656032
# Epoch 74:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.025464135899462483 valid 5.843396519517163
# Training vs. Validation Loss {'Training': 0.025464135899462483, 'Validation': 5.843396519517163} 75
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 75
# stopping at epoch74, minimum:1.319647022656032
# Epoch 75:
# Accuracy train:0.9977011680603027, val:0.516224205493927
# LOSS train 0.025988233106380158 valid 5.925958958312061
# Training vs. Validation Loss {'Training': 0.025988233106380158, 'Validation': 5.925958958312061} 76
# Training vs. Validation accuracy {'Training': 0.9977011680603027, 'Validation': 0.516224205493927} 76
# stopping at epoch75, minimum:1.319647022656032
# Epoch 76:
# Accuracy train:0.9977011680603027, val:0.516224205493927
# LOSS train 0.021359711377458138 valid 6.007352774452768
# Training vs. Validation Loss {'Training': 0.021359711377458138, 'Validation': 6.007352774452768} 77
# Training vs. Validation accuracy {'Training': 0.9977011680603027, 'Validation': 0.516224205493927} 77
# stopping at epoch76, minimum:1.319647022656032
# Epoch 77:
# Accuracy train:0.9977011680603027, val:0.516224205493927
# LOSS train 0.02505340031348169 valid 6.360223850511992
# Training vs. Validation Loss {'Training': 0.02505340031348169, 'Validation': 6.360223850511992} 78
# Training vs. Validation accuracy {'Training': 0.9977011680603027, 'Validation': 0.516224205493927} 78
# stopping at epoch77, minimum:1.319647022656032
# Epoch 78:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.016861997883428227 valid 6.346728799334796
# Training vs. Validation Loss {'Training': 0.016861997883428227, 'Validation': 6.346728799334796} 79
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 79
# stopping at epoch78, minimum:1.319647022656032
# Epoch 79:
# Accuracy train:0.9977011680603027, val:0.516224205493927
# LOSS train 0.01840037046085027 valid 6.034041986093127
# Training vs. Validation Loss {'Training': 0.01840037046085027, 'Validation': 6.034041986093127} 80
# Training vs. Validation accuracy {'Training': 0.9977011680603027, 'Validation': 0.516224205493927} 80
# stopping at epoch79, minimum:1.319647022656032
# Epoch 80:
# Accuracy train:0.9977011680603027, val:0.516224205493927
# LOSS train 0.017883826957338235 valid 6.041051529789221
# Training vs. Validation Loss {'Training': 0.017883826957338235, 'Validation': 6.041051529789221} 81
# Training vs. Validation accuracy {'Training': 0.9977011680603027, 'Validation': 0.516224205493927} 81
# stopping at epoch80, minimum:1.319647022656032
# Epoch 81:
# Accuracy train:0.9977011680603027, val:0.516224205493927
# LOSS train 0.025590446417812596 valid 6.095931665536203
# Training vs. Validation Loss {'Training': 0.025590446417812596, 'Validation': 6.095931665536203} 82
# Training vs. Validation accuracy {'Training': 0.9977011680603027, 'Validation': 0.516224205493927} 82
# stopping at epoch81, minimum:1.319647022656032
# Epoch 82:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.021569367582825096 valid 6.003513459106963
# Training vs. Validation Loss {'Training': 0.021569367582825096, 'Validation': 6.003513459106963} 83
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 83
# stopping at epoch82, minimum:1.319647022656032
# Epoch 83:
# Accuracy train:0.9977011680603027, val:0.516224205493927
# LOSS train 0.01788891259242188 valid 6.078251434029361
# Training vs. Validation Loss {'Training': 0.01788891259242188, 'Validation': 6.078251434029361} 84
# Training vs. Validation accuracy {'Training': 0.9977011680603027, 'Validation': 0.516224205493927} 84
# stopping at epoch83, minimum:1.319647022656032
# Epoch 84:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.019953017419373446 valid 6.280847299769919
# Training vs. Validation Loss {'Training': 0.019953017419373446, 'Validation': 6.280847299769919} 85
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 85
# stopping at epoch84, minimum:1.319647022656032
# Epoch 85:
# Accuracy train:0.9977011680603027, val:0.516224205493927
# LOSS train 0.02093028471889821 valid 6.151650064656012
# Training vs. Validation Loss {'Training': 0.02093028471889821, 'Validation': 6.151650064656012} 86
# Training vs. Validation accuracy {'Training': 0.9977011680603027, 'Validation': 0.516224205493927} 86
# stopping at epoch85, minimum:1.319647022656032
# Epoch 86:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.014884634663096884 valid 6.408343103947358
# Training vs. Validation Loss {'Training': 0.014884634663096884, 'Validation': 6.408343103947358} 87
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 87
# stopping at epoch86, minimum:1.319647022656032
# Epoch 87:
# Accuracy train:0.9977011680603027, val:0.516224205493927
# LOSS train 0.015177380187775601 valid 6.455320472371986
# Training vs. Validation Loss {'Training': 0.015177380187775601, 'Validation': 6.455320472371986} 88
# Training vs. Validation accuracy {'Training': 0.9977011680603027, 'Validation': 0.516224205493927} 88
# stopping at epoch87, minimum:1.319647022656032
# Epoch 88:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.012290325460278174 valid 6.47556672538605
# Training vs. Validation Loss {'Training': 0.012290325460278174, 'Validation': 6.47556672538605} 89
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 89
# stopping at epoch88, minimum:1.319647022656032
# Epoch 89:
# Accuracy train:0.9977011680603027, val:0.516224205493927
# LOSS train 0.013668912166560238 valid 6.448922226422768
# Training vs. Validation Loss {'Training': 0.013668912166560238, 'Validation': 6.448922226422768} 90
# Training vs. Validation accuracy {'Training': 0.9977011680603027, 'Validation': 0.516224205493927} 90
# stopping at epoch89, minimum:1.319647022656032
# Epoch 90:
# Accuracy train:0.9977011680603027, val:0.516224205493927
# LOSS train 0.01185962754111229 valid 6.627011608733541
# Training vs. Validation Loss {'Training': 0.01185962754111229, 'Validation': 6.627011608733541} 91
# Training vs. Validation accuracy {'Training': 0.9977011680603027, 'Validation': 0.516224205493927} 91
# stopping at epoch90, minimum:1.319647022656032
# Epoch 91:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.016929128715260464 valid 6.411249726491308
# Training vs. Validation Loss {'Training': 0.016929128715260464, 'Validation': 6.411249726491308} 92
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 92
# stopping at epoch91, minimum:1.319647022656032
# Epoch 92:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.007719553710723465 valid 6.695688621654995
# Training vs. Validation Loss {'Training': 0.007719553710723465, 'Validation': 6.695688621654995} 93
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 93
# stopping at epoch92, minimum:1.319647022656032
# Epoch 93:
# Accuracy train:0.9954022765159607, val:0.516224205493927
# LOSS train 0.011876518203114922 valid 6.5841959112009345
# Training vs. Validation Loss {'Training': 0.011876518203114922, 'Validation': 6.5841959112009345} 94
# Training vs. Validation accuracy {'Training': 0.9954022765159607, 'Validation': 0.516224205493927} 94
# stopping at epoch93, minimum:1.319647022656032
# Epoch 94:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.010555333648384973 valid 6.841994200433484
# Training vs. Validation Loss {'Training': 0.010555333648384973, 'Validation': 6.841994200433484} 95
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 95
# stopping at epoch94, minimum:1.319647022656032
# Epoch 95:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0069239047906276855 valid 6.600343858853279
# Training vs. Validation Loss {'Training': 0.0069239047906276855, 'Validation': 6.600343858853279} 96
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 96
# stopping at epoch95, minimum:1.319647022656032
# Epoch 96:
# Accuracy train:0.9954022765159607, val:0.516224205493927
# LOSS train 0.010393662335859104 valid 6.7411024951920036
# Training vs. Validation Loss {'Training': 0.010393662335859104, 'Validation': 6.7411024951920036} 97
# Training vs. Validation accuracy {'Training': 0.9954022765159607, 'Validation': 0.516224205493927} 97
# stopping at epoch96, minimum:1.319647022656032
# Epoch 97:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.010889861224727198 valid 6.7333774958325225
# Training vs. Validation Loss {'Training': 0.010889861224727198, 'Validation': 6.7333774958325225} 98
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 98
# stopping at epoch97, minimum:1.319647022656032
# Epoch 98:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.012641164834018458 valid 6.408606155595074
# Training vs. Validation Loss {'Training': 0.012641164834018458, 'Validation': 6.408606155595074} 99
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 99
# stopping at epoch98, minimum:1.319647022656032
# Epoch 99:
# Accuracy train:0.9977011680603027, val:0.516224205493927
# LOSS train 0.00982462153346701 valid 6.636271845951691
# Training vs. Validation Loss {'Training': 0.00982462153346701, 'Validation': 6.636271845951691} 100
# Training vs. Validation accuracy {'Training': 0.9977011680603027, 'Validation': 0.516224205493927} 100
# stopping at epoch99, minimum:1.319647022656032
# Epoch 100:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.012927565765990452 valid 6.423404225617351
# Training vs. Validation Loss {'Training': 0.012927565765990452, 'Validation': 6.423404225617351} 101
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 101
# stopping at epoch100, minimum:1.319647022656032
# Epoch 101:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.006938649150966244 valid 6.6669811524644045
# Training vs. Validation Loss {'Training': 0.006938649150966244, 'Validation': 6.6669811524644045} 102
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 102
# stopping at epoch101, minimum:1.319647022656032
# Epoch 102:
# Accuracy train:0.9977011680603027, val:0.516224205493927
# LOSS train 0.008762160485441034 valid 6.779300200596582
# Training vs. Validation Loss {'Training': 0.008762160485441034, 'Validation': 6.779300200596582} 103
# Training vs. Validation accuracy {'Training': 0.9977011680603027, 'Validation': 0.516224205493927} 103
# stopping at epoch102, minimum:1.319647022656032
# Epoch 103:
# Accuracy train:0.9954022765159607, val:0.516224205493927
# LOSS train 0.011395394897342405 valid 6.416209582253456
# Training vs. Validation Loss {'Training': 0.011395394897342405, 'Validation': 6.416209582253456} 104
# Training vs. Validation accuracy {'Training': 0.9954022765159607, 'Validation': 0.516224205493927} 104
# stopping at epoch103, minimum:1.319647022656032
# Epoch 104:
# Accuracy train:0.9977011680603027, val:0.516224205493927
# LOSS train 0.014220285970209674 valid 6.657538936817557
# Training vs. Validation Loss {'Training': 0.014220285970209674, 'Validation': 6.657538936817557} 105
# Training vs. Validation accuracy {'Training': 0.9977011680603027, 'Validation': 0.516224205493927} 105
# stopping at epoch104, minimum:1.319647022656032
# Epoch 105:
# Accuracy train:0.9977011680603027, val:0.516224205493927
# LOSS train 0.012056691243990579 valid 6.537400914257999
# Training vs. Validation Loss {'Training': 0.012056691243990579, 'Validation': 6.537400914257999} 106
# Training vs. Validation accuracy {'Training': 0.9977011680603027, 'Validation': 0.516224205493927} 106
# stopping at epoch105, minimum:1.319647022656032
# Epoch 106:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.008221005417660555 valid 6.768656334875795
# Training vs. Validation Loss {'Training': 0.008221005417660555, 'Validation': 6.768656334875795} 107
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 107
# stopping at epoch106, minimum:1.319647022656032
# Epoch 107:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.011615872383117676 valid 6.896853445937881
# Training vs. Validation Loss {'Training': 0.011615872383117676, 'Validation': 6.896853445937881} 108
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 108
# stopping at epoch107, minimum:1.319647022656032
# Epoch 108:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.010139369882050563 valid 6.914123017106098
# Training vs. Validation Loss {'Training': 0.010139369882050563, 'Validation': 6.914123017106098} 109
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 109
# stopping at epoch108, minimum:1.319647022656032
# Epoch 109:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.007944041005843743 valid 6.960389830384366
# Training vs. Validation Loss {'Training': 0.007944041005843743, 'Validation': 6.960389830384366} 110
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 110
# stopping at epoch109, minimum:1.319647022656032
# Epoch 110:
# Accuracy train:0.9977011680603027, val:0.516224205493927
# LOSS train 0.0073056355044669044 valid 7.231561767032959
# Training vs. Validation Loss {'Training': 0.0073056355044669044, 'Validation': 7.231561767032959} 111
# Training vs. Validation accuracy {'Training': 0.9977011680603027, 'Validation': 0.516224205493927} 111
# stopping at epoch110, minimum:1.319647022656032
# Epoch 111:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.007174140641423451 valid 6.820443828104047
# Training vs. Validation Loss {'Training': 0.007174140641423451, 'Validation': 6.820443828104047} 112
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 112
# stopping at epoch111, minimum:1.319647022656032
# Epoch 112:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.009954316922548142 valid 6.944036044051937
# Training vs. Validation Loss {'Training': 0.009954316922548142, 'Validation': 6.944036044051937} 113
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 113
# stopping at epoch112, minimum:1.319647022656032
# Epoch 113:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.005735258592969992 valid 6.885527849196691
# Training vs. Validation Loss {'Training': 0.005735258592969992, 'Validation': 6.885527849196691} 114
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 114
# stopping at epoch113, minimum:1.319647022656032
# Epoch 114:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.003949990040961315 valid 6.82745853423979
# Training vs. Validation Loss {'Training': 0.003949990040961315, 'Validation': 6.82745853423979} 115
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 115
# stopping at epoch114, minimum:1.319647022656032
# Epoch 115:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0045613369650461455 valid 6.825079868520376
# Training vs. Validation Loss {'Training': 0.0045613369650461455, 'Validation': 6.825079868520376} 116
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 116
# stopping at epoch115, minimum:1.319647022656032
# Epoch 116:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.006101311311464418 valid 6.847601377963317
# Training vs. Validation Loss {'Training': 0.006101311311464418, 'Validation': 6.847601377963317} 117
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 117
# stopping at epoch116, minimum:1.319647022656032
# Epoch 117:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.008673345638354394 valid 7.014970914636025
# Training vs. Validation Loss {'Training': 0.008673345638354394, 'Validation': 7.014970914636025} 118
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 118
# stopping at epoch117, minimum:1.319647022656032
# Epoch 118:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.00756188060305166 valid 7.0783719083238585
# Training vs. Validation Loss {'Training': 0.00756188060305166, 'Validation': 7.0783719083238585} 119
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 119
# stopping at epoch118, minimum:1.319647022656032
# Epoch 119:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0036818900526585903 valid 7.2077976693424315
# Training vs. Validation Loss {'Training': 0.0036818900526585903, 'Validation': 7.2077976693424315} 120
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 120
# stopping at epoch119, minimum:1.319647022656032
# Epoch 120:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.004037848689635707 valid 7.410965597629493
# Training vs. Validation Loss {'Training': 0.004037848689635707, 'Validation': 7.410965597629493} 121
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 121
# stopping at epoch120, minimum:1.319647022656032
# Epoch 121:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.005947311861250041 valid 7.189969830172203
# Training vs. Validation Loss {'Training': 0.005947311861250041, 'Validation': 7.189969830172203} 122
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 122
# stopping at epoch121, minimum:1.319647022656032
# Epoch 122:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0028455272285183046 valid 7.196566388947454
# Training vs. Validation Loss {'Training': 0.0028455272285183046, 'Validation': 7.196566388947454} 123
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 123
# stopping at epoch122, minimum:1.319647022656032
# Epoch 123:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.005428980533245273 valid 7.43474218811303
# Training vs. Validation Loss {'Training': 0.005428980533245273, 'Validation': 7.43474218811303} 124
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 124
# stopping at epoch123, minimum:1.319647022656032
# Epoch 124:
# Accuracy train:0.9977011680603027, val:0.516224205493927
# LOSS train 0.006964566561774435 valid 7.062029288155365
# Training vs. Validation Loss {'Training': 0.006964566561774435, 'Validation': 7.062029288155365} 125
# Training vs. Validation accuracy {'Training': 0.9977011680603027, 'Validation': 0.516224205493927} 125
# stopping at epoch124, minimum:1.319647022656032
# Epoch 125:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.004923892016945915 valid 7.263771359239237
# Training vs. Validation Loss {'Training': 0.004923892016945915, 'Validation': 7.263771359239237} 126
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 126
# stopping at epoch125, minimum:1.319647022656032
# Epoch 126:
# Accuracy train:0.9977011680603027, val:0.516224205493927
# LOSS train 0.003806790883324786 valid 7.564121366228355
# Training vs. Validation Loss {'Training': 0.003806790883324786, 'Validation': 7.564121366228355} 127
# Training vs. Validation accuracy {'Training': 0.9977011680603027, 'Validation': 0.516224205493927} 127
# stopping at epoch126, minimum:1.319647022656032
# Epoch 127:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.003964009721213105 valid 7.497726969718913
# Training vs. Validation Loss {'Training': 0.003964009721213105, 'Validation': 7.497726969718913} 128
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 128
# stopping at epoch127, minimum:1.319647022656032
# Epoch 128:
# Accuracy train:0.9977011680603027, val:0.516224205493927
# LOSS train 0.004995649304791269 valid 7.7936528369358555
# Training vs. Validation Loss {'Training': 0.004995649304791269, 'Validation': 7.7936528369358555} 129
# Training vs. Validation accuracy {'Training': 0.9977011680603027, 'Validation': 0.516224205493927} 129
# stopping at epoch128, minimum:1.319647022656032
# Epoch 129:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.004470224026590586 valid 7.136967693396899
# Training vs. Validation Loss {'Training': 0.004470224026590586, 'Validation': 7.136967693396899} 130
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 130
# stopping at epoch129, minimum:1.319647022656032
# Epoch 130:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.007490125061436133 valid 7.456587919507685
# Training vs. Validation Loss {'Training': 0.007490125061436133, 'Validation': 7.456587919507685} 131
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 131
# stopping at epoch130, minimum:1.319647022656032
# Epoch 131:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.004183655488304794 valid 7.575411036695734
# Training vs. Validation Loss {'Training': 0.004183655488304794, 'Validation': 7.575411036695734} 132
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 132
# stopping at epoch131, minimum:1.319647022656032
# Epoch 132:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.009734163593913598 valid 7.385450998374347
# Training vs. Validation Loss {'Training': 0.009734163593913598, 'Validation': 7.385450998374347} 133
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 133
# stopping at epoch132, minimum:1.319647022656032
# Epoch 133:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.003945148348892954 valid 7.454519084862251
# Training vs. Validation Loss {'Training': 0.003945148348892954, 'Validation': 7.454519084862251} 134
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 134
# stopping at epoch133, minimum:1.319647022656032
# Epoch 134:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.004869008992417631 valid 7.550127991267565
# Training vs. Validation Loss {'Training': 0.004869008992417631, 'Validation': 7.550127991267565} 135
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 135
# stopping at epoch134, minimum:1.319647022656032
# ...
# Training vs. Validation Loss {'Training': 0.0005859731007314457, 'Validation': 9.397119658333915} 255
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 255
# stopping at epoch254, minimum:1.319647022656032
# Epoch 255:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0008391812238683501 valid 9.627660070146833
# Training vs. Validation Loss {'Training': 0.0008391812238683501, 'Validation': 9.627660070146833} 256
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 256
# stopping at epoch255, minimum:1.319647022656032
# Epoch 256:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.001468409826471047 valid 9.773105893816266
# Training vs. Validation Loss {'Training': 0.001468409826471047, 'Validation': 9.773105893816266} 257
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 257
# stopping at epoch256, minimum:1.319647022656032
# Epoch 257:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0012181389955168759 valid 9.568445750645228
# Training vs. Validation Loss {'Training': 0.0012181389955168759, 'Validation': 9.568445750645228} 258
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 258
# stopping at epoch257, minimum:1.319647022656032
# Epoch 258:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.001386564102920767 valid 10.005580629621234
# Training vs. Validation Loss {'Training': 0.001386564102920767, 'Validation': 10.005580629621234} 259
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 259
# stopping at epoch258, minimum:1.319647022656032
# Epoch 259:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0014477062861921943 valid 9.591097150530134
# Training vs. Validation Loss {'Training': 0.0014477062861921943, 'Validation': 9.591097150530134} 260
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 260
# stopping at epoch259, minimum:1.319647022656032
# Epoch 260:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.000447553957532033 valid 9.67943068913051
# Training vs. Validation Loss {'Training': 0.000447553957532033, 'Validation': 9.67943068913051} 261
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 261
# stopping at epoch260, minimum:1.319647022656032
# Epoch 261:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0020107409492828247 valid 9.454559189932686
# Training vs. Validation Loss {'Training': 0.0020107409492828247, 'Validation': 9.454559189932686} 262
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 262
# stopping at epoch261, minimum:1.319647022656032
# Epoch 262:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0009861437892223794 valid 9.411625725882393
# Training vs. Validation Loss {'Training': 0.0009861437892223794, 'Validation': 9.411625725882393} 263
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 263
# stopping at epoch262, minimum:1.319647022656032
# Epoch 263:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0009692562400067055 valid 9.533449854169573
# Training vs. Validation Loss {'Training': 0.0009692562400067055, 'Validation': 9.533449854169573} 264
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 264
# stopping at epoch263, minimum:1.319647022656032
# Epoch 264:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0030871369143080137 valid 9.97144181387765
# Training vs. Validation Loss {'Training': 0.0030871369143080137, 'Validation': 9.97144181387765} 265
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 265
# stopping at epoch264, minimum:1.319647022656032
# Epoch 265:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.004146307360894174 valid 9.492290496826172
# Training vs. Validation Loss {'Training': 0.004146307360894174, 'Validation': 9.492290496826172} 266
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 266
# stopping at epoch265, minimum:1.319647022656032
# Epoch 266:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0008900151204381308 valid 9.401644842965263
# Training vs. Validation Loss {'Training': 0.0008900151204381308, 'Validation': 9.401644842965263} 267
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 267
# stopping at epoch266, minimum:1.319647022656032
# Epoch 267:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.002090266127528263 valid 9.503096308026995
# Training vs. Validation Loss {'Training': 0.002090266127528263, 'Validation': 9.503096308026995} 268
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 268
# stopping at epoch267, minimum:1.319647022656032
# Epoch 268:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0011956746159491806 valid 9.902816499982562
# Training vs. Validation Loss {'Training': 0.0011956746159491806, 'Validation': 9.902816499982562} 269
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 269
# stopping at epoch268, minimum:1.319647022656032
# Epoch 269:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0022644768240835137 valid 9.86207457951137
# Training vs. Validation Loss {'Training': 0.0022644768240835137, 'Validation': 9.86207457951137} 270
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 270
# stopping at epoch269, minimum:1.319647022656032
# Epoch 270:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.00253996140434703 valid 10.066729818071638
# Training vs. Validation Loss {'Training': 0.00253996140434703, 'Validation': 10.066729818071638} 271
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 271
# stopping at epoch270, minimum:1.319647022656032
# Epoch 271:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.001320873024765619 valid 10.388540540422712
# Training vs. Validation Loss {'Training': 0.001320873024765619, 'Validation': 10.388540540422712} 272
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 272
# stopping at epoch271, minimum:1.319647022656032
# Epoch 272:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.000511436731110073 valid 10.296272959027972
# Training vs. Validation Loss {'Training': 0.000511436731110073, 'Validation': 10.296272959027972} 273
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 273
# stopping at epoch272, minimum:1.319647022656032
# Epoch 273:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0025553017172073437 valid 9.674073355538505
# Training vs. Validation Loss {'Training': 0.0025553017172073437, 'Validation': 9.674073355538505} 274
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 274
# stopping at epoch273, minimum:1.319647022656032
# Epoch 274:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0012765360572137235 valid 9.851343291146415
# Training vs. Validation Loss {'Training': 0.0012765360572137235, 'Validation': 9.851343291146415} 275
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 275
# stopping at epoch274, minimum:1.319647022656032
# Epoch 275:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0022581702809971334 valid 10.093710490635463
# Training vs. Validation Loss {'Training': 0.0022581702809971334, 'Validation': 10.093710490635463} 276
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 276
# stopping at epoch275, minimum:1.319647022656032
# Epoch 276:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.001125022623455152 valid 9.652196747916085
# Training vs. Validation Loss {'Training': 0.001125022623455152, 'Validation': 9.652196747916085} 277
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 277
# stopping at epoch276, minimum:1.319647022656032
# Epoch 277:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0003193591910530813 valid 10.226751463753837
# Training vs. Validation Loss {'Training': 0.0003193591910530813, 'Validation': 10.226751463753837} 278
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 278
# stopping at epoch277, minimum:1.319647022656032
# Epoch 278:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0023090445253976873 valid 10.18493924822126
# Training vs. Validation Loss {'Training': 0.0023090445253976873, 'Validation': 10.18493924822126} 279
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 279
# stopping at epoch278, minimum:1.319647022656032
# Epoch 279:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0005994308468705805 valid 10.26777526310512
# Training vs. Validation Loss {'Training': 0.0005994308468705805, 'Validation': 10.26777526310512} 280
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 280
# stopping at epoch279, minimum:1.319647022656032
# Epoch 280:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0013338830374943261 valid 10.240416254316058
# Training vs. Validation Loss {'Training': 0.0013338830374943261, 'Validation': 10.240416254316058} 281
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 281
# stopping at epoch280, minimum:1.319647022656032
# Epoch 281:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0009490821096485226 valid 10.456655502319336
# Training vs. Validation Loss {'Training': 0.0009490821096485226, 'Validation': 10.456655502319336} 282
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 282
# stopping at epoch281, minimum:1.319647022656032
# Epoch 282:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0007319531065480656 valid 10.17511899130685
# Training vs. Validation Loss {'Training': 0.0007319531065480656, 'Validation': 10.17511899130685} 283
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 283
# stopping at epoch282, minimum:1.319647022656032
# Epoch 283:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0010428684399812482 valid 10.111750194004603
# Training vs. Validation Loss {'Training': 0.0010428684399812482, 'Validation': 10.111750194004603} 284
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 284
# stopping at epoch283, minimum:1.319647022656032
# Epoch 284:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0011230857788343035 valid 10.377478463309151
# Training vs. Validation Loss {'Training': 0.0011230857788343035, 'Validation': 10.377478463309151} 285
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 285
# stopping at epoch284, minimum:1.319647022656032
# Epoch 285:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.000821263960956871 valid 10.121552467346191
# Training vs. Validation Loss {'Training': 0.000821263960956871, 'Validation': 10.121552467346191} 286
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 286
# stopping at epoch285, minimum:1.319647022656032
# Epoch 286:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0008025829880683556 valid 10.219042233058385
# Training vs. Validation Loss {'Training': 0.0008025829880683556, 'Validation': 10.219042233058385} 287
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 287
# stopping at epoch286, minimum:1.319647022656032
# Epoch 287:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0006271286449852844 valid 10.035331862313408
# Training vs. Validation Loss {'Training': 0.0006271286449852844, 'Validation': 10.035331862313408} 288
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 288
# stopping at epoch287, minimum:1.319647022656032
# Epoch 288:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0004562109590386337 valid 10.306864193507604
# Training vs. Validation Loss {'Training': 0.0004562109590386337, 'Validation': 10.306864193507604} 289
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 289
# stopping at epoch288, minimum:1.319647022656032
# Epoch 289:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0006700443819599142 valid 10.006109918866839
# Training vs. Validation Loss {'Training': 0.0006700443819599142, 'Validation': 10.006109918866839} 290
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 290
# stopping at epoch289, minimum:1.319647022656032
# Epoch 290:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0008736183809477635 valid 10.177284921918597
# Training vs. Validation Loss {'Training': 0.0008736183809477635, 'Validation': 10.177284921918597} 291
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 291
# stopping at epoch290, minimum:1.319647022656032
# Epoch 291:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0009726960392568303 valid 10.17732388632638
# Training vs. Validation Loss {'Training': 0.0009726960392568303, 'Validation': 10.17732388632638} 292
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 292
# stopping at epoch291, minimum:1.319647022656032
# Epoch 292:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0002502889583411161 valid 10.192570277622767
# Training vs. Validation Loss {'Training': 0.0002502889583411161, 'Validation': 10.192570277622767} 293
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 293
# stopping at epoch292, minimum:1.319647022656032
# Epoch 293:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0006588059441955094 valid 10.235217366899763
# Training vs. Validation Loss {'Training': 0.0006588059441955094, 'Validation': 10.235217366899763} 294
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 294
# stopping at epoch293, minimum:1.319647022656032
# Epoch 294:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0001940087432475676 valid 10.315568378993444
# Training vs. Validation Loss {'Training': 0.0001940087432475676, 'Validation': 10.315568378993444} 295
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 295
# stopping at epoch294, minimum:1.319647022656032
# Epoch 295:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0005236856202166316 valid 10.159628323146276
# Training vs. Validation Loss {'Training': 0.0005236856202166316, 'Validation': 10.159628323146276} 296
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 296
# stopping at epoch295, minimum:1.319647022656032
# Epoch 296:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.00048214610598568635 valid 10.282531465802874
# Training vs. Validation Loss {'Training': 0.00048214610598568635, 'Validation': 10.282531465802874} 297
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 297
# stopping at epoch296, minimum:1.319647022656032
# Epoch 297:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0008060744160254465 valid 10.312640871320452
# Training vs. Validation Loss {'Training': 0.0008060744160254465, 'Validation': 10.312640871320452} 298
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 298
# stopping at epoch297, minimum:1.319647022656032
# Epoch 298:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.00028335960186351173 valid 10.286217280796595
# Training vs. Validation Loss {'Training': 0.00028335960186351173, 'Validation': 10.286217280796595} 299
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 299
# stopping at epoch298, minimum:1.319647022656032
# Epoch 299:
# Accuracy train:1.0, val:0.516224205493927
# LOSS train 0.0008011958621368235 valid 10.481440816606794
# Training vs. Validation Loss {'Training': 0.0008011958621368235, 'Validation': 10.481440816606794} 300
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.516224205493927} 300
# stopping at epoch299, minimum:1.319647022656032
# tensor(0.5162)

# %%
list_label = label_dict_from_config_file("D:/Tài liệu/AI/Main_course/Module 5/Week 5/Hint_light_controlling_using_hand_gesture/Hint/step0_generate_data/hand_gesture.yaml")
DATA_FOLDER_PATH="D:/Tài liệu/AI/Main_course/Module 5/Week 5/Hint_light_controlling_using_hand_gesture/Hint/step0_generate_data/data2"
testset = CustomImageDataset(os.path.join(DATA_FOLDER_PATH,"landmark_test.csv"))

# Test DataLoader instantiation
################## Your Code Here ################## Q6
''' Hoàn thành code bên dưới để  khởi tạo DataLoader cho testset with batch size
20, không cho phép shuffle
'''
test_loader = torch.utils.data.DataLoader(testset, batch_size=20, shuffle=False)
####################################################
network = NeuralNetwork()
network.load_state_dict(torch.load(best_model_path, weights_only=False))

network.eval()
acc_test = Accuracy(num_classes=len(list_label), task='MULTICLASS')
for i, test_data in enumerate(test_loader):
    test_input, test_label = test_data
    ################## Your Code Here ################## Q7
    '''Hoàn thành code bên dưới để  predict class của cử chỉ và update accuracy
    với kết quả predict và true labels
    '''
    preds = network(test_input)
    acc_test.update(preds, test_label)

    ####################################################

print(network.__class__.__name__)
print(f"Accuracy of model:{acc_test.compute().item()}")
print("========================================================================")
# Out:
# NeuralNetwork
# Accuracy of model:0.4113110601902008
# ========================================================================
